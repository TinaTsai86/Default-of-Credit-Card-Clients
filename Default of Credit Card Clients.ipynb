# %%
import pandas as pd
import numpy as numpy
import seaborn as sns


credit = pd.read_csv('/Users/wanting/Downloads/default of credit card clients.csv')

# %%
import plotly.graph_objects as go

# %%
credit[['SEX', 'EDUCATION', 'MARRIAGE']].describe()
# Out:
#                 SEX     EDUCATION      MARRIAGE
# count  30000.000000  30000.000000  30000.000000
# mean       1.603733      1.853133      1.551867
# std        0.489129      0.790349      0.521970
# min        1.000000      0.000000      0.000000
# 25%        1.000000      1.000000      1.000000
# 50%        2.000000      2.000000      2.000000
# 75%        2.000000      2.000000      2.000000
# max        2.000000      6.000000      3.000000

# %%
credit.PAY_1 = credit.PAY_1.replace({-2: 0, -1: 0})
credit.PAY_2 = credit.PAY_2.replace({-2: 0, -1: 0})
credit.PAY_3 = credit.PAY_3.replace({-2: 0, -1: 0})
credit.PAY_4 = credit.PAY_4.replace({-2: 0, -1: 0})
credit.PAY_5 = credit.PAY_5.replace({-2: 0, -1: 0})
credit.PAY_6 = credit.PAY_6.replace({-2: 0, -1: 0})

# %%
credit = credit[(credit['BILL_AMT1'] >= 0) & (credit['BILL_AMT2'] >= 0) & (credit['BILL_AMT3'] >= 0) & ( credit['BILL_AMT4'] >= 0) & (credit['BILL_AMT5'] >= 0) & (credit['BILL_AMT6'] >= 0)]

credit = credit[(credit['MARRIAGE'] != 0) & (credit['MARRIAGE'] != 3)]

credit = credit[(credit['EDUCATION'] != 4) & (credit['EDUCATION'] != 5) & (credit['EDUCATION'] != 6) & (credit['EDUCATION'] != 0) ] 

print(credit.head())
print(len(credit), sum(credit['dpnm']))
print(credit.columns)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4
# 0   1      20000    2          2         1   24      2      2      0      0  \
# 1   2     120000    2          2         2   26      0      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57      0      0      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 0  ...          0          0          0         0       689         0  \
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  dpnm
# 0         0         0         0     1
# ...

# %%
temp = credit["dpnm"].value_counts()
df = pd.DataFrame({'dpnm': temp.index,'values': temp.values})
plt.figure(figsize = (6,6))
plt.title('Default Credit Card Clients Counts\n (Not Default = 0, Default = 1)')
sns.set_color_codes("bright")
sns.barplot(x = 'dpnm', y="values", data=df)
locs, labels = plt.xticks()
plt.show()

# %%
categorical_features = ['SEX', 'EDUCATION', 'MARRIAGE']
credit_cat = credit[categorical_features]
credit_cat['dpnm'] = credit['dpnm']
for col in categorical_features:
  plt.figure(figsize=(10,5))
  fig, axes = plt.subplots(ncols=2,figsize=(13,8))
  credit[col].value_counts().plot(kind="pie",ax = axes[0],subplots=True)
  sns.countplot(x = col, hue = 'dpnm', data = credit_cat)
# Out:
# /var/folders/zk/s99_v5dn1zdghxfrhy_jf87w0000gn/T/ipykernel_25751/514424567.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = credit['PAY_1']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='PAY_1', ylabel='dpnm'>

# %%
x = credit['PAY_2']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='PAY_2', ylabel='dpnm'>

# %%
x = credit['PAY_3']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='PAY_3', ylabel='dpnm'>

# %%
x = credit['PAY_4']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='PAY_4', ylabel='dpnm'>

# %%
x = credit['PAY_5']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='PAY_5', ylabel='dpnm'>

# %%
x = credit['PAY_6']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='PAY_6', ylabel='dpnm'>

# %%
x = credit['EDUCATION']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='EDUCATION', ylabel='dpnm'>

# %%
x = credit['SEX']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='SEX', ylabel='dpnm'>

# %%
x = credit['LIMIT_BAL']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='LIMIT_BAL', ylabel='dpnm'>

# %%
x = credit['AGE']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='AGE', ylabel='dpnm'>

# %%
x = credit['MARRIAGE']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='MARRIAGE', ylabel='dpnm'>

# %%
x = credit['BILL_AMT1']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='BILL_AMT1', ylabel='dpnm'>

# %%
x = credit['PAY_AMT1']
y = credit['dpnm']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=credit, logistic=True, ci=None)
# Out:
# <Axes: xlabel='PAY_AMT1', ylabel='dpnm'>

# %%
credit = pd.get_dummies(credit,columns = ['EDUCATION','MARRIAGE', 'SEX'])

print(credit.head())
# Out:
#    ID  LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1
# 0   1      20000   24      2      2      0      0      0      0       3913  \
# 1   2     120000   26      0      2      0      0      0      2       2682
# 2   3      90000   34      0      0      0      0      0      0      29239
# 3   4      50000   37      0      0      0      0      0      0      46990
# 4   5      50000   57      0      0      0      0      0      0       8617
#
#    ...  PAY_AMT5  PAY_AMT6  dpnm  EDUCATION_1  EDUCATION_2  EDUCATION_3
# 0  ...         0         0     1        False         True        False  \
# 1  ...         0      2000     1        False         True        False
# 2  ...      1000      5000     0        False         True        False
# 3  ...      1069      1000     0        False         True        False
# 4  ...       689       679     0        False         True        False
#
#    MARRIAGE_1  MARRIAGE_2  SEX_1  SEX_2
# 0        True       False  False   True
# ...

# %%
credit.EDUCATION_1 = credit.EDUCATION_1.replace({True: 1, False: 0})
credit.EDUCATION_2 = credit.EDUCATION_1.replace({True: 1, False: 0})
credit.EDUCATION_3 = credit.EDUCATION_1.replace({True: 1, False: 0})
credit.MARRIAGE_1 = credit.MARRIAGE_1.replace({True: 1, False: 0})
credit.MARRIAGE_2 = credit.MARRIAGE_2.replace({True: 1, False: 0})
credit.SEX_1 = credit.SEX_1.replace({True: 1, False: 0})
credit.SEX_2 = credit.SEX_2.replace({True: 1, False: 0})

print(credit.head())
# Out:
#    ID  LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1
# 0   1      20000   24      2      2      0      0      0      0       3913  \
# 1   2     120000   26      0      2      0      0      0      2       2682
# 2   3      90000   34      0      0      0      0      0      0      29239
# 3   4      50000   37      0      0      0      0      0      0      46990
# 4   5      50000   57      0      0      0      0      0      0       8617
#
#    ...  PAY_AMT5  PAY_AMT6  dpnm  EDUCATION_1  EDUCATION_2  EDUCATION_3
# 0  ...         0         0     1            0            0            0  \
# 1  ...         0      2000     1            0            0            0
# 2  ...      1000      5000     0            0            0            0
# 3  ...      1069      1000     0            0            0            0
# 4  ...       689       679     0            0            0            0
#
#    MARRIAGE_1  MARRIAGE_2  SEX_1  SEX_2
# 0           1           0      0      1
# ...

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

##################################

### Metrics ###
from sklearn import metrics
from sklearn.metrics import f1_score,confusion_matrix, mean_squared_error, mean_absolute_error, classification_report, roc_auc_score, roc_curve, precision_score, recall_score

# %%
print(credit.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27290 entries, 0 to 29999
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           27290 non-null  int64
#  1   LIMIT_BAL    27290 non-null  int64
#  2   AGE          27290 non-null  int64
#  3   PAY_1        27290 non-null  int64
#  4   PAY_2        27290 non-null  int64
#  5   PAY_3        27290 non-null  int64
#  6   PAY_4        27290 non-null  int64
#  7   PAY_5        27290 non-null  int64
#  8   PAY_6        27290 non-null  int64
#  9   BILL_AMT1    27290 non-null  int64
#  10  BILL_AMT2    27290 non-null  int64
#  11  BILL_AMT3    27290 non-null  int64
#  12  BILL_AMT4    27290 non-null  int64
#  13  BILL_AMT5    27290 non-null  int64
#  14  BILL_AMT6    27290 non-null  int64
#  15  PAY_AMT1     27290 non-null  int64
#  16  PAY_AMT2     27290 non-null  int64
#  17  PAY_AMT3     27290 non-null  int64
#  18  PAY_AMT4     27290 non-null  int64
# ...

# %%
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
data = credit.drop(['ID'], axis=1)

# %%
# Check for duplicate rows.
print(f"There are {data.duplicated().sum()} duplicate rows in the data set.")

# Remove duplicate rows.
data=data.drop_duplicates()
print("The duplicate rows were removed.")
# Out:
# There are 39 duplicate rows in the data set.
# The duplicate rows were removed.

# %%
print(f"There are {data.isna().any().sum()} cells with null values in the data set.")
# Out:
# There are 0 cells with null values in the data set.

# %%
# Distinguish attribute columns and class column.
y=data['dpnm']
X=data[data.columns].drop(['dpnm'], axis=1)
print(X.head)
# Out:
# <bound method NDFrame.head of        LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1
# 0          20000   24      2      2      0      0      0      0       3913  \
# 1         120000   26      0      2      0      0      0      2       2682
# 2          90000   34      0      0      0      0      0      0      29239
# 3          50000   37      0      0      0      0      0      0      46990
# 4          50000   57      0      0      0      0      0      0       8617
# ...          ...  ...    ...    ...    ...    ...    ...    ...        ...
# 29994      80000   34      2      2      2      2      2      2      72557
# 29995     220000   39      0      0      0      0      0      0     188948
# 29996     150000   43      0      0      0      0      0      0       1683
# 29997      30000   37      4      3      2      0      0      0       3565
# 29999      50000   46      0      0      0      0      0      0      47929
#
# ...

# %%
# Split to train and test sets. 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)
print(X_train)
# Out:
#        LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1
# 28211     250000   40      0      0      0      0      0      0       2971  \
# 6085      140000   37      0      0      2      2      2      2     124375
# 10196      50000   41      2      3      2      2      2      2      29463
# 11636      50000   27      0      0      0      0      0      0      48603
# 1276      480000   54      0      0      0      0      0      0      17189
# ...          ...  ...    ...    ...    ...    ...    ...    ...        ...
# 27278     360000   41      0      0      0      0      0      0        316
# 3199      180000   34      1      0      0      0      0      0     149172
# 29462     150000   27      0      0      0      0      0      0      85500
# 7290       80000   33      0      0      0      0      0      0      69937
# 27350     200000   32      0      0      0      0      0      0       1125
#
# ...

# %%
X_train = pd.DataFrame(X_train, columns = X.columns)

X_test = pd.DataFrame(X_test, columns=X.columns)

# %%
# Initialize a decision tree estimator.
tr = tree.DecisionTreeClassifier(max_depth = 3)

# Train the estimator.
tr.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(tr, feature_names=X_train.columns, filled=True)

# %%
# Make predictions.
tr_pred=tr.predict(X_test)

# CV score
tr_cv=cross_val_score(tr, X_train, y_train, cv=10).mean()

# %%
# Accuracy: 1 is perfect prediction.
print('Accuracy: %.3f' % tr.score(X_test, y_test))

# Cross-Validation accuracy
print('Cross-validation accuracy: %0.3f' % tr_cv)

# Precision
print('Precision: %.3f' % precision_score(y_test, tr_pred))

# Recall
print('Recall: %.3f' % recall_score(y_test, tr_pred))

# f1 score: best value at 1 (perfect precision and recall) and worst at 0.
print('F1 score: %.3f' % f1_score(y_test, tr_pred))
# Out:
# Accuracy: 0.808
# Cross-validation accuracy: 0.823
# Precision: 0.662
# Recall: 0.366
# F1 score: 0.472

# %%
tr_matrix = confusion_matrix(y_test,tr_pred)
sns.set(font_scale=1.3)
plt.subplots(figsize=(8, 8))
sns.heatmap(tr_matrix,annot=True, cbar=False, cmap='prism',linewidth=0.5,fmt="d")
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix for Decision tree');

# %%
forest = RandomForestClassifier(n_jobs = -1, random_state=42)

# %%
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
forest_pred = forest.predict(X_test)
forest_cv=cross_val_score(forest, X_train, y_train, cv=10).mean()

# %%
# Accuracy: 1 is perfect prediction.
print('Accuracy: %.3f' % forest.score(X_test, y_test))

# Cross-Validation accuracy
print('Cross-validation accuracy: %0.3f' % forest_cv)

# Precision
print('Precision: %.3f' % precision_score(y_test, forest_pred))

# Recall
print('Recall: %.3f' % recall_score(y_test, forest_pred))

# f1 score: best value at 1 (perfect precision and recall) and worst at 0.
print('F1 score: %.3f' % f1_score(y_test, forest_pred))
# Out:
# Accuracy: 0.801
# Cross-validation accuracy: 0.817
# Precision: 0.631
# Recall: 0.367
# F1 score: 0.464

# %%
# Plot confusion matrix for Multi-layer Perceptron.
matrix = confusion_matrix(y_test,forest_pred)
sns.set(font_scale=1.3)
plt.subplots(figsize=(8, 8))
sns.heatmap(matrix,annot=True, cbar=False, cmap='prism',linewidth=0.5,fmt="d")
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix for RF');

# %%
from imblearn.over_sampling import SMOTE


oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
bins = [20,30,40,50,60,70,80]
names = ['21-30','31-40','41-50','51-60','61-70','71-80']
credit['AGE_BIN'] = pd.cut(x=credit.AGE, bins=bins, labels=names, right=True)

age_cnt = credit.AGE_BIN.value_counts()
age_0 = (credit.AGE_BIN[credit['dpnm'] == 0].value_counts())
age_1 = (credit.AGE_BIN[credit['dpnm'] == 1].value_counts())

plt.subplots(figsize=(8,5))
# sns.barplot(data=defaulters, x='AGE_BIN', y='LIMIT_BAL', hue='def_pay', ci=0)
plt.bar(age_0.index, age_0.values, label='0')
plt.bar(age_1.index, age_1.values, label='1')
for x,y in zip(names,age_0):
    plt.text(x,y,y,fontsize=12)
for x,y in zip(names,age_1):
    plt.text(x,y,y,fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Number of clients in each age group", fontsize=15)
plt.legend(loc='upper right', fontsize=15)
plt.show()

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_fit = scaler.fit_transform(X_train)
X_test_fit = scaler.transform(X_test)
print(X_test.head())
# Out:
#        LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1
# 3829      100000   35      0      0      0      0      0      0       5830  \
# 17700     170000   49      0      0      0      0      0      0      12769
# 7452      350000   32      0      0      0      0      0      0          0
# 22291      30000   32      0      0      0      2      0      0      27395
# 1354       50000   27      0      0      0      0      0      0       9877
#
#        BILL_AMT2  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  EDUCATION_1  EDUCATION_2
# 3829        6694  ...       500      1349      1691            0            0  \
# 17700      13557  ...      4500      5415      6000            0            0
# 7452           0  ...         0         0         0            1            1
# 22291      25947  ...      1200      1200      1200            0            0
# 1354       10800  ...         0         0     10620            0            0
#
# ...

# %%
print(X_train)
# Out:
#        LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1
# 28211     250000   40      0      0      0      0      0      0       2971  \
# 6085      140000   37      0      0      2      2      2      2     124375
# 10196      50000   41      2      3      2      2      2      2      29463
# 11636      50000   27      0      0      0      0      0      0      48603
# 1276      480000   54      0      0      0      0      0      0      17189
# ...          ...  ...    ...    ...    ...    ...    ...    ...        ...
# 27278     360000   41      0      0      0      0      0      0        316
# 3199      180000   34      1      0      0      0      0      0     149172
# 29462     150000   27      0      0      0      0      0      0      85500
# 7290       80000   33      0      0      0      0      0      0      69937
# 27350     200000   32      0      0      0      0      0      0       1125
#
# ...

# %%
print(X_train_fit)
# Out:
# [[ 0.65067701  0.50840245 -0.46780444 ... -1.08490294 -0.80725346
#    0.80725346]
#  [-0.19580331  0.18146334 -0.46780444 ... -1.08490294 -0.80725346
#    0.80725346]
#  [-0.88837813  0.61738215  2.12130616 ... -1.08490294 -0.80725346
#    0.80725346]
#  ...
#  [-0.11885056 -0.90833367 -0.46780444 ...  0.92174145  1.2387683
#   -1.2387683 ]
#  [-0.65751986 -0.25445546 -0.46780444 ...  0.92174145 -0.80725346
#    0.80725346]
#  [ 0.26591323 -0.36343516 -0.46780444 ...  0.92174145  1.2387683
#   -1.2387683 ]]

# %%
# Initialize a Logistic Regression estimator.
logreg=LogisticRegression(multi_class='ovr', random_state=25)

# Train the estimator.
logreg.fit(X_train_fit,y_train)
# Out:
# LogisticRegression(multi_class='ovr', random_state=25)

# %%
# Make predictions.
log_pred=logreg.predict(X_test_fit)

#CV score
logreg_cv=cross_val_score(logreg, X_train_fit, y_train, cv=10).mean()

# %%
# Accuracy: 1 is perfect prediction.
print('Accuracy: %.3f' % logreg.score(X_test_fit, y_test))

# Cross-Validation accuracy
print('Cross-validation accuracy: %0.3f' % logreg_cv)

# Precision
print('Precision: %.3f' % precision_score(y_test, log_pred))

# Recall
print('Recall: %.3f' % recall_score(y_test, log_pred))

# f1 score: best value at 1 (perfect precision and recall) and worst at 0.
print('F1 score: %.3f' % f1_score(y_test, log_pred))
# Out:
# Accuracy: 0.806
# Cross-validation accuracy: 0.822
# Precision: 0.671
# Recall: 0.338
# F1 score: 0.450

# %%
# Plot confusion matrix for Logistic Regression.
logreg_matrix = confusion_matrix(y_test,log_pred)
sns.set(font_scale=1.3)
plt.subplots(figsize=(8, 8))
sns.heatmap(logreg_matrix, annot=True, cbar=False, cmap='prism',linewidth=0.5,fmt="d")
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix for Logistic Regression');

# %%
# Initialize a Multi-layer Perceptron classifier.
mlp = MLPClassifier(hidden_layer_sizes=(12,5),max_iter=1000, random_state=25,shuffle=True, verbose=False)

# Train the classifier.
mlp.fit(X_train_fit, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(12, 5), max_iter=1000, random_state=25)

# %%
# Make predictions.
mlp_pred = mlp.predict(X_test_fit)

# CV score
mlp_cv=cross_val_score(mlp, X_train_fit, y_train, cv=10).mean()

# %%
# Accuracy: 1 is perfect prediction.
print('Accuracy: %.3f' % mlp.score(X_test_fit, y_test))

# Cross-Validation accuracy
print('Cross-validation accuracy: %0.3f' % mlp_cv)

# Precision
print('Precision: %.3f' % precision_score(y_test, mlp_pred))

# Recall
print('Recall: %.3f' % recall_score(y_test, mlp_pred))

# f1 score: best value at 1 (perfect precision and recall) and worst at 0.
print('F1 score: %.3f' % f1_score(y_test, mlp_pred))
# Out:
# Accuracy: 0.804
# Cross-validation accuracy: 0.820
# Precision: 0.636
# Recall: 0.381
# F1 score: 0.477

# %%
# Plot confusion matrix for Multi-layer Perceptron.
matrix = confusion_matrix(y_test,mlp_pred)
sns.set(font_scale=1.3)
plt.subplots(figsize=(8, 8))
sns.heatmap(matrix,annot=True, cbar=False, cmap='prism',linewidth=0.5,fmt="d")
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix for MLP');

# %%
riskmodel = smf.logit(formula = 'dpnm ~ LIMIT_BAL + AGE + PAY_1 + PAY_2 + PAY_3 + PAY_4 + PAY_5 + PAY_6 + BILL_AMT1 + BILL_AMT2 + BILL_AMT3 + BILL_AMT4 + BILL_AMT5 + BILL_AMT6 + PAY_AMT1 + PAY_AMT2 + PAY_AMT3 + PAY_AMT4 + PAY_AMT5 + PAY_AMT6 + EDUCATION_1 + EDUCATION_2 + EDUCATION_3 + SEX_1 + SEX_2 + MARRIAGE_1 + MARRIAGE_2', data = credit).fit()  
riskmodel.summary()
# Out:
# ...
#          Current function value: 0.447362
#          Iterations: 35
# /Users/wanting/anaconda3/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   dpnm   No. Observations:                27290
# Model:                          Logit   Df Residuals:                    27266
# Method:                           MLE   Df Model:                           23
# Date:                Wed, 24 May 2023   Pseudo R-squ.:                  0.1651
# Time:                        15:42:55   Log-Likelihood:                -12209.
# converged:                      False   LL-Null:                       -14624.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...

# %%
print(riskmodel.pvalues)
print(riskmodel.params)
print(data.columns)
# Out:
# Intercept                NaN
# LIMIT_BAL       8.092991e-16
# AGE             1.373350e-01
# PAY_1          1.726803e-267
# PAY_2           2.276172e-01
# PAY_3           7.111477e-04
# PAY_4           6.116923e-02
# PAY_5           3.998741e-03
# PAY_6           2.752009e-08
# BILL_AMT1       3.642975e-03
# BILL_AMT2       9.699862e-02
# BILL_AMT3       8.086527e-02
# BILL_AMT4       9.550246e-01
# BILL_AMT5       9.319275e-01
# BILL_AMT6       6.969964e-01
# PAY_AMT1        1.012914e-06
# PAY_AMT2        1.054260e-05
# PAY_AMT3        4.330356e-01
# PAY_AMT4        2.448054e-01
# PAY_AMT5        4.591005e-02
# PAY_AMT6        2.246241e-03
# EDUCATION_1     1.000000e+00
# EDUCATION_2              NaN
# EDUCATION_3              NaN
# SEX_1           9.999997e-01
# SEX_2           9.999995e-01
# MARRIAGE_1      9.999993e-01
# MARRIAGE_2      9.999990e-01
# dtype: float64
# Intercept     -7.956620e-01
# LIMIT_BAL     -1.328448e-06
# AGE            2.929570e-03
# ...

# %%
p_values = riskmodel.pvalues.tolist()[1:]
coefficients = riskmodel.params.tolist()[1:]
feature_name = data.columns.tolist()[:20]+data.columns.tolist()[21:]
#print(feature_name.index('dpnm'))

# %%
print(p_values)
# Out:
# [8.092991041379026e-16, 0.13733502468007744, 1.7268026125630709e-267, 0.22761717315861707, 0.0007111477014443122, 0.06116922602506785, 0.003998740854116895, 2.752008789794659e-08, 0.003642974880749698, 0.09699862200912, 0.08086527341853494, 0.9550245532361945, 0.9319274776641128, 0.6969963909739447, 1.0129143777284765e-06, 1.0542601027652196e-05, 0.4330355552999601, 0.2448053594126266, 0.04591004543356353, 0.0022462414185121945, 0.9999999984109167, nan, nan, 0.9999996547122413, 0.9999994948534303, 0.9999993160696585, 0.9999989509016817]

# %%
print(coefficients)
# Out:
# [-1.3284476290215118e-06, 0.0029295702339804473, 0.9195740916047255, 0.03317900624908371, 0.10028681026565682, 0.06143029672536694, 0.10091857069818337, 0.16541235657302272, -3.4115593104795346e-06, 2.5632871676711633e-06, 2.397536966769956e-06, 7.756174911170555e-08, -1.3797763979443433e-07, -5.112958449945103e-07, -1.170067310821356e-05, -1.0171707901405385e-05, -1.4166862572276737e-06, -2.174894814657448e-06, -4.107103781095244e-06, -4.906637542249612e-06, 0.006472539701292722, 0.0064725402169948055, 0.006472540339404504, -0.33018427510589576, -0.46547919108036523, -0.3140048238281083, -0.48166006482535045]

# %%
print(feature_name)
print(len(p_values),len(coefficients),len(feature_name))
# Out:
# ['LIMIT_BAL', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'EDUCATION_1', 'EDUCATION_2', 'EDUCATION_3', 'MARRIAGE_1', 'MARRIAGE_2', 'SEX_1', 'SEX_2']
# 27 27 27

# %%
feature_dict = {}
for i, feature in enumerate(feature_name):
    feature_dict[feature] = i

# %%
plt.scatter(p_values, coefficients)
plt.xlabel('p_values')
plt.ylabel('coefficients')
plt.title('P-value vs. Coefficient')

#annotate PAY_1
plt.annotate(feature_name[2], (p_values[2], coefficients[2] ))

#annotate PAY_2-6
pay = ['PAY_'+str(i) for i in range(2,7)]
lines_pay = []
for name in pay:
    lines_pay.append([p_values[feature_dict[name]],0.3])
    lines_pay.append([coefficients[feature_dict[name]],0.6])

i = 0
while i<len(lines_pay):
    plt.plot(lines_pay[i],lines_pay[i+1], color='yellow',linestyle='--')
    i  += 2
plt.scatter(0.3,0.6,marker = 'o')
plt.annotate('PAY_2 - PAY_6', (0.3, 0.6 ))

#annotate AGE
plt.annotate('AGE', (0.14, -0.05 ))

#annotate BILL_AMT1-6
bill = ['BILL_AMT'+str(i) for i in range(1,7)]
lines_bill = []
for name in bill:
    lines_bill.append([p_values[feature_dict[name]],0.2])
    lines_bill.append([coefficients[feature_dict[name]],-0.3])

i = 0
while i<len(lines_bill):
    plt.plot(lines_bill[i],lines_bill[i+1], color='green',linestyle='--')
    i  += 2
plt.scatter(0.2,-0.3,marker = 'o')
plt.annotate('BILL_AMT1 - BILL_AMT6', (0.22, -0.35))

#annotate LIMIT_BAL
plt.annotate('LIMIT_BAL_', (-0.02, -0.1))

#annotate PAY_AMT1-6

PAY_AMT = ['PAY_AMT'+str(i) for i in range(1,7)]
lines_PAY_AMT = []
for name in PAY_AMT:
    lines_PAY_AMT.append([p_values[feature_dict[name]],0.5])
    lines_PAY_AMT.append([coefficients[feature_dict[name]],0.3])

i = 0
while i<len(lines_PAY_AMT):
    plt.plot(lines_PAY_AMT[i],lines_PAY_AMT[i+1], color='purple',linestyle='--')
    i  += 2
plt.scatter(0.2,-0.3,marker = 'o')
plt.annotate('PAY_AMT1 - PAY_AMT6', (0.52, 0.33))


plt.annotate(feature_name[20], (p_values[20], coefficients[20] ))

plt.annotate(feature_name[23], (p_values[23], coefficients[23] ))

plt.annotate(feature_name[24], (p_values[24], coefficients[24] ))

plt.annotate(feature_name[24], (p_values[24], coefficients[24] ))

plt.annotate('SEX_1', (0.9, -0.3))
plt.annotate('SEX_2', (0.9, -0.53))


# line1_x = [8.092991041379026e-16, 0.3]
# line1_y = [-1.3284476290215118e-06, 0.6]
# line2_x = [1.7268026125630709e-267, 0.3]
# line2_y = [0.919574091604725, 0.6]
# plt.plot(line1_x,line1_y, color='yellow',linestyle='--')
# plt.plot(line2_x,line2_y, color='yellow',linestyle='--')


#plt.plot(x, y, 'o', color='red')

# Annotate P-value
plt.annotate('P-value < 0.05', xy=(0.05, -0.4), xytext=(0.2, -0.5),
             arrowprops=dict(facecolor='red', arrowstyle='->'))

plt.axvline(x=0.05, color='red', linestyle='--')


plt.figure(figsize=(100, 100))
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Predict probabilities for the test data.
logreg_probs = logreg.predict_proba(X_test_fit)

# Keep Probabilities of the positive class only.
logreg_probs = logreg_probs[:, 1]

# Predict propabilities for the test data.
tr_probs = tr.predict_proba(X_test)

# Keep Probabilities of the positive class only.
tr_probs = tr_probs[:, 1]

# Predict probabilities for the test data.
mlp_probs = mlp.predict_proba(X_test_fit)

# Keep probabilities of the positive class only.
mlp_probs = mlp_probs[:, 1]

# Predict probabilities for the test data.
forest_probs = forest.predict_proba(X_test)

# Keep probabilities of the positive class only.
forest_probs = forest_probs[:, 1]


# Compute the AUC Score.
auc_logreg = roc_auc_score(y_test, logreg_probs)
print('AUC: %.2f' % auc_logreg)# Compute the AUC Score.

auc_tr = roc_auc_score(y_test, tr_probs)
print('AUC: %.2f' % auc_tr)

auc_forest = roc_auc_score(y_test, forest_probs)
print('AUC: %.2f' % auc_forest)

auc_mlp = roc_auc_score(y_test, mlp_probs)
print('AUC: %.2f' % auc_mlp)


# Recall
print('Recall: %.3f' % recall_score(y_test, mlp_pred))

# f1 score: best value at 1 (perfect precision and recall) and worst at 0.
print('F1 score: %.3f' % f1_score(y_test, mlp_pred))
# Out:
# AUC: 0.75
# AUC: 0.72
# AUC: 0.75
# AUC: 0.77
# Recall: 0.381
# F1 score: 0.477

# %%
metrics=['Accuracy', 'CV accuracy', 'Precision','Recall','F1','ROC AUC']

# Plot metrics.
fig = go.Figure(data=[
    go.Bar(name='Logistic Regression', x=metrics,
           y=[logreg.score(X_test_fit, y_test),logreg_cv,precision_score(y_test, log_pred),recall_score(y_test, log_pred),f1_score(y_test, log_pred),auc_logreg]),
     go.Bar(name='Random Forest', x=metrics,
           y=[forest.score(X_test, y_test),forest_cv,precision_score(y_test, forest_pred),recall_score(y_test, forest_pred),f1_score(y_test, forest_pred),auc_forest]),
    go.Bar(name='Decision tree', x=metrics,
           y=[tr.score(X_test, y_test),tr_cv,precision_score(y_test, tr_pred),recall_score(y_test, tr_pred),f1_score(y_test, tr_pred),auc_tr]),
    go.Bar(name='Neural Network', x=metrics,
           y=[mlp.score(X_test_fit, y_test),mlp_cv,precision_score(y_test, mlp_pred),recall_score(y_test, mlp_pred),f1_score(y_test, mlp_pred),auc_mlp]),])
   

fig.update_layout(title_text='Metrics for each model',
                  barmode='group',xaxis_tickangle=-45,bargroupgap=0.05)
fig.show()
# Out:
# <div>                            <div id="37c01dff-ca29-434f-b47d-db72da184f65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37c01dff-ca29-434f-b47d-db72da184f65")) {                    Plotly.newPlot(                        "37c01dff-ca29-434f-b47d-db72da184f65",                        [{"name":"Logistic Regression","x":["Accuracy","CV accuracy","Precision","Recall","F1","ROC AUC"],"y":[0.8058953033268101,0.8217558009276207,0.6708074534161491,0.3380281690140845,0.44953173777315303,0.7538269982513652],"type":"bar"},{"name":"Random Forest","x":["Accuracy","CV accuracy","Precision","Recall","F1","ROC AUC"],"y":[0.801247553816047,0.8165660223451281,0.6308243727598566,0.36724047991653624,0.46422683811407844,0.7490736969436939],"type":"bar"},{"name":"
# ...

# %%
# Get the ROC curves.
logreg_fpr, logreg_tpr,logreg_thresholds = roc_curve(y_test, logreg_probs)
mlp_fpr, mlp_tpr, mlp_thresholds = roc_curve(y_test, mlp_probs)
tr_fpr, tr_tpr,tr_thresholds = roc_curve(y_test, tr_probs)
forest_fpr, forest_tpr, forest_thresholds = roc_curve(y_test, forest_probs)

# Plot the ROC curve.
plt.figure(figsize=(8,8))
plt.plot(mlp_fpr, mlp_tpr, color='purple', label='MLP ROC (AUC= %0.2f)'% auc_mlp)
plt.plot(tr_fpr, tr_tpr, color='green', label='DT ROC (AUC= %0.2f)'% auc_tr)
plt.plot(logreg_fpr, logreg_tpr, color='blue', label='logreg ROC (AUC= %0.2f)'% auc_logreg)
plt.plot(forest_fpr, forest_tpr, color='red', label='RF ROC (AUC= %0.2f)'% auc_forest)

plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--',label='random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend()
plt.show()
